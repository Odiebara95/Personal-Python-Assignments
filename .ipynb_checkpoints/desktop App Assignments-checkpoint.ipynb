# %%
from tkinter import *

# %%
def add(x,y):
    addition= x+y
    return addition

def subt(x,y):
    subtraction=(x-y)
    return subtraction

def mult(x,y):
    multiplication= x*y
    return multiplication

def divide(x,y):
    if y!=0:
        division= x/y
    else:
        print("Division not possible")
    return division
            
def computeadd():
    n1=int(entry1.get())
    n2=int(entry2.get())
    result["text"]="Result is: "+str(add(n1,n2))

def computesubt():
    n1=int(entry1.get())
    n2=int(entry2.get())
    result["text"]="Result is: "+str(subt(n1,n2))
    
def computemult():
    n1=int(entry1.get())
    n2=int(entry2.get())
    result["text"]="Result is: "+str(mult(n1,n2))
    
def computedivide():
    n1=int(entry1.get())
    n2=int(entry2.get())
    result["text"]="Result is: "+str(divide(n1,n2))

root = Tk(className=" Arithemtic Operations")
root.geometry("250x200")
root.config(bg="blue")
f1=Frame(root)
f1.pack()
f2=Frame(root)
f2.pack()
f3=Frame(root)
f3.pack()
f4=Frame(root)
f4.pack()
f5=Frame(root)
f5.pack()
f6=Frame(root)
f6.pack()
f7=Frame(root)
f7.pack()

Label(f1,text="Number one", pady=10).pack(side=LEFT)
entry1=Entry(f1)
entry1.pack()
Label(f2,text="Number Two").pack(side=LEFT)
entry2=Entry(f2)
entry2.pack()
Button(f3,text="add", bg= "green", command=computeadd).pack(side=LEFT)
Button(f4,text="subtract", bg= "grey", command=computesubt).pack(side=LEFT)
Button(f5,text="multiply", bg= "violet", command=computemult).pack(side=LEFT)
Button(f6,text="divide", bg= "indigo", command=computedivide).pack(side=LEFT)
result=Label(f7)
result.pack()

root.mainloop()

# %%
def readData(a,b):
    file = open("data.txt",mode="w")
    file.write(" ")
    file.close()

def storeData():
    n1=(entry1.get())
    n2=(entry2.get())
    readData(n1,n2)
    
master = Tk()
f1=Frame(master)
f1.pack()
f2=Frame(master)
f2.pack()
f3=Frame(master)
f3.pack()

Label(f1,text="Amount").pack()
entry1=Entry(f1)
entry1.pack()
Label(f2,text="Description").pack()
entry2=Entry(f2)
entry2.pack()
Button(text="Save", bg= "green", command=storeData).pack()
master.mainloop()
